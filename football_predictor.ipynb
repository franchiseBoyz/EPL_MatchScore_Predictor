# %% [markdown]
# ## 2022 Premier League Machine Learning Predictor using Random Forests

# %%
# Importing pandas package for data manipulation/transformation
import pandas as pd

# %%
# Loading and viewing the data
matches = pd.read_csv('./data/matches.csv', index_col=0)
matches.head(10)
# Out:
#           date   time            comp         round  day venue result   gf  \
# 1   2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2   2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3   2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4   2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6   2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# 8   2021-09-25  12:30  Premier League   Matchweek 6  Sat  Away      W  1.0
# 10  2021-10-03  16:30  Premier League   Matchweek 7  Sun  Away      D  2.0
# 11  2021-10-16  15:00  Premier League   Matchweek 8  Sat  Home      W  2.0
# 13  2021-10-23  17:30  Premier League   Matchweek 9  Sat  Away      W  4.0
# 15  2021-10-30  15:00  Premier League  Matchweek 10  Sat  Home      L  0.0
#
#      ga        opponent  ...  match report  notes    sh   sot  dist   fk   pk  \
# ...

# %%
# Inspecting the data
matches.shape
# Out:
# (1389, 27)

# %%
matches.describe()
# Out:
#                 gf           ga           xg          xga         poss  \
# count  1389.000000  1389.000000  1389.000000  1389.000000  1389.000000
# mean      1.335493     1.380850     1.304176     1.338445    49.702664
# std       1.274235     1.291049     0.767268     0.789360    12.401897
# min       0.000000     0.000000     0.000000     0.000000    18.000000
# 25%       0.000000     0.000000     0.700000     0.700000    40.000000
# 50%       1.000000     1.000000     1.200000     1.200000    50.000000
# 75%       2.000000     2.000000     1.800000     1.800000    59.000000
# max       9.000000     9.000000     4.600000     5.000000    82.000000
#
#          attendance  notes           sh          sot         dist  \
# count    693.000000    0.0  1389.000000  1389.000000  1388.000000
# mean   36089.963925    NaN    12.153348     4.041037    17.011527
# std    17797.991778    NaN     5.268876     2.403866     2.988364
# ...

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1389 entries, 1 to 42
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1389 non-null   object
#  1   time          1389 non-null   object
#  2   comp          1389 non-null   object
#  3   round         1389 non-null   object
#  4   day           1389 non-null   object
#  5   venue         1389 non-null   object
#  6   result        1389 non-null   object
#  7   gf            1389 non-null   float64
#  8   ga            1389 non-null   float64
#  9   opponent      1389 non-null   object
#  10  xg            1389 non-null   float64
#  11  xga           1389 non-null   float64
#  12  poss          1389 non-null   float64
#  13  attendance    693 non-null    float64
#  14  captain       1389 non-null   object
#  15  formation     1389 non-null   object
#  16  referee       1389 non-null   object
#  17  match report  1389 non-null   object
# ...

# %% [markdown]
# ## Investigating the missing values

# %%
# Check for total number of matches
matches['team'].value_counts()
# Out:
# Southampton                 72
# Brighton and Hove Albion    72
# Manchester United           72
# West Ham United             72
# Newcastle United            72
# Burnley                     71
# Leeds United                71
# Crystal Palace              71
# Manchester City             71
# Wolverhampton Wanderers     71
# Tottenham Hotspur           71
# Arsenal                     71
# Leicester City              70
# Chelsea                     70
# Aston Villa                 70
# Everton                     70
# Liverpool                   38
# Fulham                      38
# West Bromwich Albion        38
# Sheffield United            38
# Brentford                   34
# Watford                     33
# Norwich City                33
# Name: team, dtype: int64

# %%
# Check for total number of matchweeks
matches['round'].value_counts()
# Out:
# Matchweek 1     39
# Matchweek 16    39
# Matchweek 34    39
# Matchweek 32    39
# Matchweek 31    39
# Matchweek 29    39
# Matchweek 28    39
# Matchweek 26    39
# Matchweek 25    39
# Matchweek 24    39
# Matchweek 23    39
# Matchweek 2     39
# Matchweek 19    39
# Matchweek 17    39
# Matchweek 20    39
# Matchweek 15    39
# Matchweek 5     39
# Matchweek 3     39
# Matchweek 13    39
# Matchweek 12    39
# Matchweek 4     39
# Matchweek 11    39
# Matchweek 10    39
# Matchweek 9     39
# Matchweek 8     39
# Matchweek 14    39
# Matchweek 7     39
# Matchweek 6     39
# Matchweek 30    37
# Matchweek 27    37
# Matchweek 22    37
# Matchweek 21    37
# Matchweek 18    37
# Matchweek 33    32
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 38    20
# Name: round, dtype: int64

# %% [markdown]
# ## Cleaning the dataset

# %%
# Check the column data types
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
# Convert the date time to date/time format
matches['date'] = pd.to_datetime(matches['date'])
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                     float64
# pkatt                  float64
# season                   int64
# team                    object
# dtype: object

# %% [markdown]
# # Creating predictor columns

# %%
# Converting the venue column to numerical
matches['venue_code'] = matches['venue'].astype('category').cat.codes
matches.head(10)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# 8  2021-09-25  12:30  Premier League   Matchweek 6  Sat  Away      W  1.0
# 10 2021-10-03  16:30  Premier League   Matchweek 7  Sun  Away      D  2.0
# 11 2021-10-16  15:00  Premier League   Matchweek 8  Sat  Home      W  2.0
# 13 2021-10-23  17:30  Premier League   Matchweek 9  Sat  Away      W  4.0
# 15 2021-10-30  15:00  Premier League  Matchweek 10  Sat  Home      L  0.0
#
#      ga        opponent  ...  notes    sh   sot  dist   fk   pk pkatt season  \
# ...

# %%
# Assigning each team a code
matches['opp_code'] = matches['opponent'].astype('category').cat.codes
matches.head(10)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# 8  2021-09-25  12:30  Premier League   Matchweek 6  Sat  Away      W  1.0
# 10 2021-10-03  16:30  Premier League   Matchweek 7  Sun  Away      D  2.0
# 11 2021-10-16  15:00  Premier League   Matchweek 8  Sat  Home      W  2.0
# 13 2021-10-23  17:30  Premier League   Matchweek 9  Sat  Away      W  4.0
# 15 2021-10-30  15:00  Premier League  Matchweek 10  Sat  Home      L  0.0
#
#      ga        opponent  ...    sh   sot  dist   fk   pk pkatt season  \
# 1   1.0       Tottenham  ...  18.0   4.0  16.9  1.0  0.0   0.0   2022
# ...

# %%
# Create an hour column to check the time of the day the matches were played.
matches['hours'] = matches['time'].str.replace(":.+", "", regex=True).astype('int')
matches.head(10)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# 8  2021-09-25  12:30  Premier League   Matchweek 6  Sat  Away      W  1.0
# 10 2021-10-03  16:30  Premier League   Matchweek 7  Sun  Away      D  2.0
# 11 2021-10-16  15:00  Premier League   Matchweek 8  Sat  Home      W  2.0
# 13 2021-10-23  17:30  Premier League   Matchweek 9  Sat  Away      W  4.0
# 15 2021-10-30  15:00  Premier League  Matchweek 10  Sat  Home      L  0.0
#
#      ga        opponent  ...   sot  dist   fk   pk pkatt season  \
# 1   1.0       Tottenham  ...   4.0  16.9  1.0  0.0   0.0   2022
# ...

# %%
# Create a the day of the week when matches were played
matches['day_code'] = matches['date'].dt.dayofweek
matches.head(10)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# 8  2021-09-25  12:30  Premier League   Matchweek 6  Sat  Away      W  1.0
# 10 2021-10-03  16:30  Premier League   Matchweek 7  Sun  Away      D  2.0
# 11 2021-10-16  15:00  Premier League   Matchweek 8  Sat  Home      W  2.0
# 13 2021-10-23  17:30  Premier League   Matchweek 9  Sat  Away      W  4.0
# 15 2021-10-30  15:00  Premier League  Matchweek 10  Sat  Home      L  0.0
#
#      ga        opponent  ...  dist   fk   pk  pkatt season             team  \
# 1   1.0       Tottenham  ...  16.9  1.0  0.0    0.0   2022  Manchester City
# ...

# %%
matches['target'] = (matches['result'] == 'W').astype('int')
matches.head(10)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# 8  2021-09-25  12:30  Premier League   Matchweek 6  Sat  Away      W  1.0
# 10 2021-10-03  16:30  Premier League   Matchweek 7  Sun  Away      D  2.0
# 11 2021-10-16  15:00  Premier League   Matchweek 8  Sat  Home      W  2.0
# 13 2021-10-23  17:30  Premier League   Matchweek 9  Sat  Away      W  4.0
# 15 2021-10-30  15:00  Premier League  Matchweek 10  Sat  Home      L  0.0
#
#      ga        opponent  ...   fk   pk  pkatt  season             team  \
# 1   1.0       Tottenham  ...  1.0  0.0    0.0    2022  Manchester City
# ...

# %% [markdown]
# ## Creating the model

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
# Training the model
train = matches[matches['date'] < '2022-01-01']

# Test data
test = matches[matches['date'] > '2022-01-01']

# %%
# Predictors
predictors = ['venue_code','opp_code','hours', 'day_code']

# %%
# Fitting the model to the data
rf.fit(train[predictors], train['target'])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
# Making predictions
preds = rf.predict(test[predictors])

# %%
# Check for the model accuracey
from sklearn.metrics import accuracy_score

acc = accuracy_score(test['target'], preds)
acc
# Out:
# 0.6123188405797102

# %%
# Create a dataframe to show actual vs ppredictions
combined = pd.DataFrame(dict(actual=test['target'], prediction=preds))

# Plotting a crosstab
pd.crosstab(index=combined['actual'], columns=combined['prediction'])
# Out:
# prediction    0   1
# actual
# 0           141  31
# 1            76  28

# %%
from sklearn.metrics import precision_score

precision_score(test['target'], preds)
# Out:
# 0.4745762711864407

# %% [markdown]
# ## Using Rolling Averages to improve precision

# %%
grouped_matches = matches.groupby('team')
group = grouped_matches.get_group('Manchester City').sort_values('date')
group.head(10)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2020-09-21  20:15  Premier League   Matchweek 2  Mon  Away      W  3.0
# 2  2020-09-27  16:30  Premier League   Matchweek 3  Sun  Home      L  2.0
# 4  2020-10-03  17:30  Premier League   Matchweek 4  Sat  Away      D  1.0
# 5  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Home      W  1.0
# 7  2020-10-24  12:30  Premier League   Matchweek 6  Sat  Away      D  1.0
# 9  2020-10-31  12:30  Premier League   Matchweek 7  Sat  Away      W  1.0
# 11 2020-11-08  16:30  Premier League   Matchweek 8  Sun  Home      D  1.0
# 12 2020-11-21  17:30  Premier League   Matchweek 9  Sat  Away      L  0.0
# 14 2020-11-28  15:00  Premier League  Matchweek 10  Sat  Home      W  5.0
# 16 2020-12-05  15:00  Premier League  Matchweek 11  Sat  Home      W  2.0
#
#      ga        opponent  ...   fk   pk  pkatt  season             team  \
# 0   1.0          Wolves  ...  2.0  1.0    1.0    2021  Manchester City
# ...

# %%
# Rolling averages function
def rolling_averages(group, cols, new_cols):
    group = group.sort_values('date')
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ['gf','ga','sh','sot','dist','fk','pk','pkatt']
new_cols = [f"{c}_rolling" for c in cols]
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_ave = rolling_averages(group, cols, new_cols)
rolling_ave
# Out:
#          date   time            comp         round  day venue result   gf  \
# 5  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Home      W  1.0
# 7  2020-10-24  12:30  Premier League   Matchweek 6  Sat  Away      D  1.0
# 9  2020-10-31  12:30  Premier League   Matchweek 7  Sat  Away      W  1.0
# 11 2020-11-08  16:30  Premier League   Matchweek 8  Sun  Home      D  1.0
# 12 2020-11-21  17:30  Premier League   Matchweek 9  Sat  Away      L  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 42 2022-03-14  20:00  Premier League  Matchweek 29  Mon  Away      D  0.0
# 44 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Away      W  2.0
# 46 2022-04-10  16:30  Premier League  Matchweek 32  Sun  Home      D  2.0
# 49 2022-04-20  20:00  Premier League  Matchweek 30  Wed  Home      W  3.0
# 50 2022-04-23  15:00  Premier League  Matchweek 34  Sat  Home      W  5.0
#
#      ga        opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# ...

# %%
matches_rolling = matches.groupby('team').apply(lambda x: rolling_averages(x,cols,new_cols))
matches_rolling = matches_rolling.droplevel('team')
matches_rolling
# Out:
#          date   time            comp         round  day venue result   gf  \
# 6  2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W  2.0
# 7  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L  0.0
# 9  2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 11 2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# 13 2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 32 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Away      W  1.0
# 33 2022-03-18  20:00  Premier League  Matchweek 30  Fri  Home      L  2.0
# 34 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home      W  2.0
# 35 2022-04-08  20:00  Premier League  Matchweek 32  Fri  Away      L  0.0
# 36 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L  0.0
#
#      ga         opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# ...

# %%
matches_rolling.index = range(matches_rolling.shape[0])
matches_rolling
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W  2.0
# 1    2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L  0.0
# 2    2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 3    2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# 4    2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L  0.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 1312 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Away      W  1.0
# 1313 2022-03-18  20:00  Premier League  Matchweek 30  Fri  Home      L  2.0
# 1314 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home      W  2.0
# 1315 2022-04-08  20:00  Premier League  Matchweek 32  Fri  Away      L  0.0
# 1316 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L  0.0
#
# ...

# %% [markdown]
# ## Retraining the model using rolling averages

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)
error
# Out:
# 0.625

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)
combined.head(20)
# Out:
#      actual  predicted       date         team        opponent result
# 55        0          0 2022-01-23      Arsenal         Burnley      D
# 56        1          0 2022-02-10      Arsenal          Wolves      W
# 57        1          0 2022-02-19      Arsenal       Brentford      W
# 58        1          1 2022-02-24      Arsenal          Wolves      W
# 59        1          1 2022-03-06      Arsenal         Watford      W
# 60        1          1 2022-03-13      Arsenal  Leicester City      W
# 61        0          1 2022-03-16      Arsenal       Liverpool      L
# 62        1          0 2022-03-19      Arsenal     Aston Villa      W
# 63        0          0 2022-04-04      Arsenal  Crystal Palace      L
# 64        0          0 2022-04-09      Arsenal        Brighton      L
# 65        0          0 2022-04-16      Arsenal     Southampton      L
# 66        1          0 2022-04-20      Arsenal         Chelsea      W
# ...

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"} 
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])
merged.tail(30)
# Out:
#      actual_x  predicted_x       date                   team_x  \
# 232         0            0 2022-04-16                  Watford
# 233         0            0 2022-04-23                  Watford
# 234         1            1 2022-01-12          West Ham United
# 235         0            0 2022-01-16          West Ham United
# 236         0            0 2022-01-22          West Ham United
# 237         1            0 2022-02-08          West Ham United
# 238         0            0 2022-02-13          West Ham United
# 239         0            0 2022-02-19          West Ham United
# 240         1            1 2022-02-27          West Ham United
# 241         1            0 2022-03-13          West Ham United
# 242         0            0 2022-03-20          West Ham United
# 243         1            0 2022-04-03          West Ham United
# 244         0            0 2022-04-10          West Ham United
# 245         0            0 2022-04-17          West Ham United
# ...

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# 1    27
# 0    13
# Name: actual_x, dtype: int64
